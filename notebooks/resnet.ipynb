# %% [markdown]
# <a href="https://colab.research.google.com/github/KenzaB27/segmentation-of-pelvic-bone/blob/main/src/resnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Environment Setup

# %%
# !nvidia-smi
# Out:
# Sat May 29 09:13:25 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    23W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/KenzaB27/segmentation-of-pelvic-bone.git
# !pip install SimpleITK
# !pip install tensorflow_addons
# %cd /content/segmentation-of-pelvic-bone/src
# Out:
# Collecting tensorflow_addons
#   Downloading https://files.pythonhosted.org/packages/66/4b/e893d194e626c24b3df2253066aa418f46a432fdb68250cde14bf9bb0700/tensorflow_addons-0.13.0-cp37-cp37m-manylinux2010_x86_64.whl (679kB)
#      |████████████████████████████████| 686kB 14.9MB/s
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.7/dist-packages (from tensorflow_addons) (2.7.1)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.13.0

# %%
# !git pull
# Out:
# Already up to date.

# %%
import sys
sys.path.append('../src/')
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import SimpleITK as sitk
import analysis as ana
import numpy as np 
import importlib

import tensorflow_addons as tfa
import tensorflow as tf 
tfk = tf.keras
tfkl = tfk.layers

# %%
PATH = "/content/drive/My Drive/KTH/HL2027/"
DATA_PATH = PATH +'data/'

# %% [markdown]
# ## Load Data

# %%
# %%time
importlib.reload(ana)
data = ana.PelvicData(root_path=PATH)
# Out:
# CPU times: user 7.52 s, sys: 495 ms, total: 8.01 s
# Wall time: 8.05 s

# %%
data.cmn_img_3c[42].shape
# Out:
# (291, 300, 300, 3)

# %%
X_train, y_train, X_val, y_val = data.X_train_3C, data.y_train, data.X_val_3C, data.y_val
X_train = tf.image.per_image_standardization(X_train)
X_val = tf.image.per_image_standardization(X_val)

# %% [markdown]
# ## ResNet V2

# %%
input = tfkl.Input([None, None, 3], dtype = tf.int16)
x = tf.cast(input, tf.float32)
x = tfk.applications.resnet_v2.preprocess_input(x)
resnet_model = tfk.applications.ResNet50V2(weights="imagenet", include_top=False, pooling="max")
resnet_output = resnet_model(x)
hidden_layer = tfkl.Dense(128, activation='relu')(resnet_output)
hl_reg = tfkl.Dropout(0.2)(hidden_layer)
output_layer = tf.keras.layers.Dense(1, activation='sigmoid')(hl_reg)
model = tf.keras.models.Model(inputs=input, outputs=output_layer)

# %%
model.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_11 (InputLayer)        [(None, None, None, 3)]   0
# _________________________________________________________________
# tf.cast_5 (TFOpLambda)       (None, None, None, 3)     0
# _________________________________________________________________
# tf.math.truediv_5 (TFOpLambd (None, None, None, 3)     0
# _________________________________________________________________
# tf.math.subtract_5 (TFOpLamb (None, None, None, 3)     0
# _________________________________________________________________
# resnet50v2 (Functional)      (None, 2048)              23564800
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               262272
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 129
# =================================================================
# Total params: 23,827,201
# Trainable params: 23,781,761
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional InceptionV3 layers
resnet_model.trainable = False
for layer in resnet_model.layers:
    layer.trainable = False

# compile the model (should be done *after* setting layers to non-trainable)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001, decay=1e-3)
model.compile(optimizer=optimizer, loss='binary_crossentropy', 
              metrics=['acc'])

# %%
checkpoint_filepath = PATH + '/checkpoint/resnet/'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_acc',
    mode='max',
    save_best_only=True)
history = model.fit(x=X_train, y=y_train, epochs=50, batch_size=32, validation_data=(X_val, y_val), callbacks=[model_checkpoint_callback])
model.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/50
# 25/25 [==============================] - 12s 338ms/step - loss: 15.2440 - acc: 0.7966 - val_loss: 5.0950 - val_acc: 0.8837
# Epoch 2/50
# 25/25 [==============================] - 6s 239ms/step - loss: 8.0324 - acc: 0.7979 - val_loss: 5.1401 - val_acc: 0.8837
# Epoch 3/50
# 25/25 [==============================] - 6s 239ms/step - loss: 6.2567 - acc: 0.8355 - val_loss: 1.9686 - val_acc: 0.8837
# Epoch 4/50
# 25/25 [==============================] - 6s 238ms/step - loss: 5.1035 - acc: 0.8225 - val_loss: 1.1658 - val_acc: 0.8953
# Epoch 5/50
50
# 25/25 [==============================] - 6s 238ms/step - loss: 0.0452 - acc: 0.9793 - val_loss: 0.0312 - val_acc: 0.9884
# Epoch 32/50
# 25/25 [==============================] - 6s 239ms/step - loss: 0.0548 - acc: 0.9767 - val_loss: 0.0099 - val_acc: 1.0000
# Epoch 33/50
# 25/25 [==============================] - 6s 238ms/step - loss: 0.0547 - acc: 0.9715 - val_loss: 0.0129 - val_acc: 1.0000
# Epoch 34/50
# 25/25 [==============================] - 6s 238ms/step - loss: 0.0481 - acc: 0.9832 - val_loss: 0.0128 - val_acc: 1.0000
# Epoch 35/50
# 25/25 [==============================] - 6s 238ms/step - loss: 0.0508 - acc: 0.9754 - val_loss: 0.0113 - val_acc: 1.0000
# Epoch 36/50
# 25/25 [==============================] - 6s 239ms/step - loss: 0.0481 - acc: 0.9806 - val_loss: 0.0161 - val_acc: 0.9884
# Epoch 37/50
# 25/25 [==============================] - 6s 238ms/step - loss: 0.0455 - acc: 0.9780 - val_loss: 0.0091 - val_acc: 1.0000
# Epoch 38/50
# 25/25 [==============================] - 6s 238ms/step - loss: 0.0348 - acc: 0.9883 - val_loss: 0.0092 - val_acc: 1.0000
# Epoch 39/50
# 25/25 [==============================] - 6s 239ms/step - loss: 0.0378 - acc: 0.9832 - val_loss: 0.0106 - val_acc: 1.0000
# Epoch 40/50
# 25/25 [==============================] - 6s 238ms/step - loss: 0.0350 - acc: 0.9858 - val_loss: 0.0106 - val_acc: 1.0000
# Epoch 41/50
# 25/25 [==============================] - 6s 238ms/step - loss: 0.0295 - acc: 0.9896 - val_loss: 0.0066 - val_acc: 1.0000
# Epoch 42/50
# 25/25 [==============================] - 6s 238ms/step - loss: 0.0473 - acc: 0.9793 - val_loss: 0.0103 - val_acc: 1.0000
# Epoch 43/50
# 25/25 [==============================] - 6s 238ms/step - loss: 0.0444 - acc: 0.9845 - val_loss: 0.0102 - val_acc: 1.0000
# Epoch 44/50
# 25/25 [==============================] - 6s 238ms/step - loss: 0.0378 - acc: 0.9819 - val_loss: 0.0096 - val_acc: 1.0000
# Epoch 45/50
# 25/25 [==============================] - 6s 238ms/step - loss: 0.0372 - acc: 0.9858 - val_loss: 0.0079 - val_acc: 1.0000
# Epoch 46/50
# 25/25 [==============================] - 6s 238ms/step - loss: 0.0369 - acc: 0.9845 - val_loss: 0.0241 - val_acc: 0.9884
# Epoch 47/50
# 25/25 [==============================] - 6s 239ms/step - loss: 0.0472 - acc: 0.9845 - val_loss: 0.0253 - val_acc: 0.9884
# Epoch 48/50
# 25/25 [==============================] - 6s 238ms/step - loss: 0.0474 - acc: 0.9832 - val_loss: 0.0110 - val_acc: 1.0000
# Epoch 49/50
# 25/25 [==============================] - 6s 238ms/step - loss: 0.1109 - acc: 0.9573 - val_loss: 0.0263 - val_acc: 0.9884
# Epoch 50/50
# 25/25 [==============================] - 6s 238ms/step - loss: 0.0513 - acc: 0.9819 - val_loss: 0.0204 - val_acc: 0.9884

# %%
plt.figure()
plt.plot(history.history["loss"], label="training loss")
plt.plot(history.history["val_loss"], label="validation loss")
plt.title("Loss for Resnet model")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(history.history["acc"], label="training accuracy")
plt.plot(history.history["val_acc"], label="validation accuracy")
plt.title("Accuracy for Resnet model")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# # Normal CNN

# %%
X_train, X_val = tf.constant(X_train), tf.constant(X_val)
X_train, X_val = tf.image.per_image_standardization(X_train), tf.image.per_image_standardization(X_val)

# %%
model = tfk.Sequential([
            tfkl.InputLayer([300, 300, 3]),
            tfkl.Conv2D(32,(3,3),padding = 'same',activation = 'relu'),
            tfkl.MaxPool2D((2,2)),
            tfkl.Conv2D(64,(3,3),padding = 'same',activation = 'relu'),
            tfkl.MaxPool2D((2,2)),
            tfkl.Conv2D(128,(3,3),padding = 'same',activation = 'relu'),
            tfkl.MaxPool2D((2,2)),
            tfkl.Conv2D(256,(3,3),padding = 'same',activation = 'relu'),
            tfkl.MaxPool2D((2,2)),
            tfkl.Flatten(),
            tfkl.Dense(512,activation='relu'),
            tfkl.Dropout(0.5),
            tfkl.Dense(64,activation='relu'),
            tfkl.Dropout(0.5),
            tfkl.Dense(1, activation='sigmoid')
])

model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['acc'])

# %%
checkpoint_filepath = PATH + '/checkpoint/cnn/'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_acc',
    mode='max',
    save_best_only=True)
history = model.fit(x=X_train, y=y_train, epochs=25, batch_size=32, validation_data=(X_val, y_val), callbacks=[model_checkpoint_callback])
model.load_weights(checkpoint_filepath)
# Out:
# Epoch 1/25
# 26/26 [==============================] - 19s 96ms/step - loss: 0.5932 - acc: 0.8589 - val_loss: 0.1301 - val_acc: 0.9302
# Epoch 2/25
# 26/26 [==============================] - 2s 63ms/step - loss: 0.1096 - acc: 0.9497 - val_loss: 0.0158 - val_acc: 1.0000
# Epoch 3/25
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0710 - acc: 0.9730 - val_loss: 0.0523 - val_acc: 0.9767
# Epoch 4/25
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0741 - acc: 0.9706 - val_loss: 0.0094 - val_acc: 1.0000
# Epoch 5/25
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0375 - acc: 0.9865 - val_loss: 4.3802e-04 - val_acc: 1.0000
# Epoch 6/25
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0306 - acc: 0.9914 - val_loss: 8.5157e-04 - val_acc: 1.0000
# Epoch 7/25
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0308 - acc: 0.9890 - val_loss: 0.0040 - val_acc: 1.0000
# Epoch 8/25
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0190 - acc: 0.9902 - val_loss: 5.8576e-06 - val_acc: 1.0000
# Epoch 9/25
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0170 - acc: 0.9951 - val_loss: 1.1261e-05 - val_acc: 1.0000
# Epoch 10/25
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0301 - acc: 0.9902 - val_loss: 1.4383e-04 - val_acc: 1.0000
# Epoch 11/25
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0307 - acc: 0.9877 - val_loss: 7.7471e-04 - val_acc: 1.0000
# Epoch 12/25
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0262 - acc: 0.9902 - val_loss: 0.0020 - val_acc: 1.0000
# Epoch 13/25
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0295 - acc: 0.9902 - val_loss: 6.5462e-04 - val_acc: 1.0000
# Epoch 14/25
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0308 - acc: 0.9902 - val_loss: 5.8845e-06 - val_acc: 1.0000
# Epoch 15/25
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0097 - acc: 0.9951 - val_loss: 3.7538e-06 - val_acc: 1.0000
# Epoch 16/25
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0229 - acc: 0.9914 - val_loss: 0.0027 - val_acc: 1.0000
# Epoch 17/25
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0289 - acc: 0.9914 - val_loss: 2.5333e-04 - val_acc: 1.0000
# Epoch 18/25
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0118 - acc: 0.9963 - val_loss: 9.9229e-06 - val_acc: 1.0000
# Epoch 19/25
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0132 - acc: 0.9975 - val_loss: 0.0013 - val_acc: 1.0000
# Epoch 20/25
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0100 - acc: 0.9963 - val_loss: 4.0673e-06 - val_acc: 1.0000
# Epoch 21/25
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0040 - acc: 0.9975 - val_loss: 7.1769e-07 - val_acc: 1.0000
# Epoch 22/25
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0101 - acc: 0.9963 - val_loss: 2.5100e-04 - val_acc: 1.0000
# Epoch 23/25
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0076 - acc: 0.9963 - val_loss: 2.1832e-05 - val_acc: 1.0000
# Epoch 24/25
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0129 - acc: 0.9963 - val_loss: 2.8599e-04 - val_acc: 1.0000
# Epoch 25/25
# 26/26 [==============================] - 2s 62ms/step - loss: 0.0028 - acc: 0.9988 - val_loss: 5.8785e-07 - val_acc: 1.0000

# %%
plt.figure()
plt.plot(history.history["loss"], label="training loss")
plt.plot(history.history["val_loss"], label="validation loss")
plt.title("Loss for CNN model")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.figure()
plt.plot(history.history["acc"], label="training accuracy")
plt.plot(history.history["val_acc"], label="validation accuracy")
plt.title("Accuracy for CNN model")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# # Test Performance on Common Images

# %%
# %%time
for id, cmn_img in data.cmn_img.items():
  X_flat = np.array([x.flatten() for x in cmn_img])
  X_flat = data.scaler.transform(X_flat)
  X = X_flat.reshape(cmn_img.shape)
  X = np.array(
            [np.repeat(x[None, ...], 3, axis=0).T for x in X])
  y_pred = model.predict(X)
  argmax = np.argmax(y_pred)
  plt.figure()
  
  plt.subplot(121)
  plt.plot(y_pred)
  plt.title(f"Probability for case {id}")

  plt.subplot(122)
  plt.imshow(data.cmn_img[id][argmax], cmap="gray")
  plt.show()
# Out:
# CPU times: user 5.48 s, sys: 917 ms, total: 6.39 s
# Wall time: 5.96 s
